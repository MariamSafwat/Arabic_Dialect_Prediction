# %%
import requests
import json
import pandas as pd
import csv

# %%
# defining the api-endpoint url
url = "https://recruitment.aimtechnologies.co/ai-tasks"

# %%
# data to be sent to api
data = [
"1055620304465215616", "1057418989293485952"
]

# %%
# response_API = requests.get(url)
# print(response_API.status_code)
# data1 = response_API.text
# print(data1)

# %%
# post data as json and save the result dictionary
res = requests.post(url, json = data)

# %%
# print(type(res.json()))
# Out:
# <class 'dict'>

# %%
data3 = res.json()

# %%
print(data3)
# Out:
# {'1055620304465215616': '@MahmoudWaked7 @maganenoo في طريق مطروح مركز بهيج  والمركز الي الي جمبه اسمه ايه😂😂', '1057418989293485952': '@mycousinvinnyys @hanyamikhail1 متهيالي دي شكولاته الهالوين  فين المحل ده'}

# %%
for key, value in data3.items():
  print('key:', key)
  print('value:', value)
# Out:
# key: 1055620304465215616
# value: @MahmoudWaked7 @maganenoo في طريق مطروح مركز بهيج  والمركز الي الي جمبه اسمه ايه😂😂
# key: 1057418989293485952
# value: @mycousinvinnyys @hanyamikhail1 متهيالي دي شكولاته الهالوين  فين المحل ده

# %%
# load data from csv file
df = pd.read_csv('/content/drive/MyDrive/Dialect_Identification/dialect_dataset.csv')

# %%
df.head()
# Out:
#                     id dialect
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ

# %%
i = 0
num_rows = df.shape[0]
arr = []
text_arr = []
while i < num_rows:
  for j in range(i, (i+1000)):
    if j >= num_rows:
      break
    # add ids to array
    arr.append(str(df['id'][j]))
  # post data as json and save the result as dictionary
  ans = requests.post(url, json = arr)
  res = ans.json()
  # save result text values as array of strings 
  a = [*res.values()]
  text_arr += a
  #print(text_arr)
  arr = []
  i += 1000

# %%
# for i in text_arr:
#   print(i)
#   print('_______')
# Out:
# @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .
# _______
# @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. حيونه ووحشيه .. وتطلبون من الغرب يحترمكم ويؤمن بدينكم ولاينعتكم بالإرهاب ..
# _______
# @KanaanRema مبين من كلامه خليجي
# _______
# @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐
# _______
# @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺
# _______

# %%
df['text'] = text_arr

# %%
df
# Out:
#                          id dialect  \
# 0       1175358310087892992      IQ
# 1       1175416117793349632      IQ
# 2       1175450108898565888      IQ
# 3       1175471073770573824      IQ
# 4       1175496913145217024      IQ
# ...                     ...     ...
# 458192  1019484980282580992      BH
# 458193  1021083283709407232      BH
# 458194  1017477537889431552      BH
# 458195  1022430374696239232      BH
# 458196  1022409931029458944      BH
#
#                                                      text
# 0        @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .
# 1       @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...
# 2                         @KanaanRema مبين من كلامه خليجي
# 3              @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐
# 4                      @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺
# ...                                                   ...
# 458192              @Al_mhbaa_7 مبسوطين منك اللي باسطانا😅
# 458193       @Zzainabali @P_ameerah والله ماينده ابش يختي
# 458194  @Al_mhbaa_7 شو عملنا لك حنا تهربي مننا احنا مس...
# 458195        @haneenalmwla الله يبارك فيها وبالعافيه 😋😋😋
# 458196          @jolnar121 السحله ضيفي ي بتطلع لك سحليه😅😅
#
# [458197 rows x 3 columns]

# %%
df.to_csv('dialect_full.csv', quoting=csv.QUOTE_NONNUMERIC, index=False)

# %%
df_full = pd.read_csv('/content/dialect_full.csv')

# %%
df_full
# Out:
#                          id dialect  \
# 0       1175358310087892992      IQ
# 1       1175416117793349632      IQ
# 2       1175450108898565888      IQ
# 3       1175471073770573824      IQ
# 4       1175496913145217024      IQ
# ...                     ...     ...
# 458192  1019484980282580992      BH
# 458193  1021083283709407232      BH
# 458194  1017477537889431552      BH
# 458195  1022430374696239232      BH
# 458196  1022409931029458944      BH
#
#                                                      text
# 0        @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .
# 1       @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...
# 2                         @KanaanRema مبين من كلامه خليجي
# 3              @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐
# 4                      @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺
# ...                                                   ...
# 458192              @Al_mhbaa_7 مبسوطين منك اللي باسطانا😅
# 458193       @Zzainabali @P_ameerah والله ماينده ابش يختي
# 458194  @Al_mhbaa_7 شو عملنا لك حنا تهربي مننا احنا مس...
# 458195        @haneenalmwla الله يبارك فيها وبالعافيه 😋😋😋
# 458196          @jolnar121 السحله ضيفي ي بتطلع لك سحليه😅😅
#
# [458197 rows x 3 columns]
